# %%
from google.colab import drive
import tensorflow as tf
from tensorflow import keras
from keras.layers import Input, concatenate, Conv2DTranspose, Conv2D, MaxPooling2D, Dropout
from keras import regularizers
from keras.models import Model
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as img
import os
import imageio
import cv2
# %matplotlib inline
# from google.colab.patches import cv2_imshow
# import cv2 as cv
#Replace cv2.imshow() to cv2_imshow()
# import numpy as np

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
working_directory = '/content/drive/MyDrive/DLproject'
original_img_dic = f'{working_directory}/original_images/'
# masked_img_dic = f'{working_directory}/RGB_color_image_masks/RGB_color_image_masks/'
masked_img_dic = f'{working_directory}/label_images_semantic/'

# %%
final_h,final_w = 96,128
# final_h,final_w = 512,512
org_image_list = os.listdir(original_img_dic)
masked_image_list = os.listdir(masked_img_dic)
org_image_list = sorted([original_img_dic+i for i in org_image_list])
masked_image_list = sorted([masked_img_dic+i for i in masked_image_list])

train_org_image_list = org_image_list[:350]
train_masked_image_list = masked_image_list[:350]

test_org_image_list = org_image_list[350:400]
test_masked_image_list = masked_image_list[350:400]
# for i in range(len(train_org_image_list)):

  #  print(train_org_image_list[i],train_masked_image_list[i])
# x = np.random.randint((0,400))

# n = 222
# org_image = img.imread(train_org_image_list[n])
# print(org_image.shape)
# masked_image = img.imread(train_masked_image_list[n])
# print(masked_image.shape)

# fig ,arr  = plt.subplots(1,2,figsize=(15,10))
# arr[0].imshow(org_image)
# arr[0].set_title('Original Image')
# arr[1].imshow(masked_image)
# arr[1].set_title('Mask')
# plt.show()

# def resize(org_image,masked_image) :
#     org_image = tf.image.resize(org_image,(512,512),method='nearest')
#     masked_image = tf.image.resize(masked_image,(512,512),method='nearest')
#     return org_image , masked_image

# i,j = resize(org_image,masked_image)

# print(i.shape)
# # masked_image = img.imread(train_masked_image_list[n])
# print(j.shape)

# fig ,arr  = plt.subplots(1,2,figsize=(15,10))
# arr[0].imshow(i)
# arr[0].set_title('Original Image after resize')
# arr[1].imshow(j)
# arr[1].set_title('Masked image after resize')
# plt.show()

# %%
def convolution_layer(inputs = None,filters = 32,dropout = 0,max_pooling = True):
    conv = Conv2D(filters,kernel_size = 3,activation='relu',padding='same',kernel_initializer=tf.keras.initializers.HeNormal())(inputs)
    conv = Conv2D(filters,kernel_size = 3,activation='relu',padding='same',kernel_initializer=tf.keras.initializers.HeNormal())(conv)
    if dropout > 0:
        conv = Dropout(dropout)(conv)
    if max_pooling:
        next_layer = MaxPooling2D(pool_size=(2,2))(conv)
    else:
        next_layer = conv

    skip_connection = conv
    return next_layer, skip_connection


def upsampling(expansive_input,contractive_input,filters =32,dropout = 0):
    up = Conv2DTranspose(filters,kernel_size = 3,strides=(2,2),padding='same')(expansive_input)
    merge = concatenate([up, contractive_input], axis=3)
    conv = Conv2D(filters,kernel_size = 3,activation='relu',padding='same',kernel_initializer=tf.keras.initializers.HeNormal())(merge)
    if dropout > 0:
        conv = Dropout(dropout)(conv)
    conv = Conv2D(filters,kernel_size = 3,activation='relu',padding='same',kernel_initializer=tf.keras.initializers.HeNormal())(conv)
    return conv

# %%
def Unet(input_size = (final_h,final_w,3),filters = 32,classes = 23):
    inputs = Input(input_size)

    #encoding block
    c_1 = convolution_layer(inputs,filters,dropout=0.1)
    c_2 = convolution_layer(c_1[0],2*filters,dropout=0.2)
    c_3 = convolution_layer(c_2[0],4*filters,dropout=0.4)
    c_4 = convolution_layer(c_3[0],8*filters,dropout=0.4)
    c_5 = convolution_layer(c_4[0],16*filters,dropout=0.4)
    c_6 = convolution_layer(c_5[0],32*filters,dropout=0.4,max_pooling=None)

    u_6 = upsampling(c_6[0],c_5[1],16*filters,dropout = 0.45)
    u_7 = upsampling(u_6,c_4[1],8*filters,dropout = 0.45)
    u_8 = upsampling(u_7,c_3[1],4*filters,dropout = 0.4)
    u_9 = upsampling(u_8,c_2[1],2*filters,dropout = 0.2)
    u_10 = upsampling(u_9,c_1[1],filters,dropout = 0.1)

    conv10 = Conv2D(filters,kernel_size = 3,activation='relu',padding='same',kernel_initializer='he_normal')(u_10)

    conv11 = Conv2D(classes, kernel_size=1,padding='same', activation='softmax')(conv10)
    # conv11 = Conv2D(classes, kernel_size=1, padding='same')(conv10)

    model = Model(inputs=inputs, outputs=conv11)
    return model

Unet_model = Unet((final_h,final_w,3))
Unet_model.summary()
# Unet_model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])
Unet_model.compile(optimizer='adam', loss=['sparse_categorical_crossentropy'], metrics=['accuracy'])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 96, 128, 3)]         0         []
#
#  conv2d (Conv2D)             (None, 96, 128, 32)          896       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 96, 128, 32)          9248      ['conv2d[0][0]']
#
#  dropout (Dropout)           (None, 96, 128, 32)          0         ['conv2d_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 48, 64, 32)           0         ['dropout[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 48, 64, 64)           18496     ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 48, 64, 64)           36928     ['conv2d_2[0][0]']
#
#  dropout_1 (Dropout)         (None, 48, 64, 64)           0         ['conv2d_3[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 24, 32, 64)           0         ['dropout_1[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 24, 32, 128)          73856     ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 24, 32, 128)          147584    ['conv2d_4[0][0]']
#
#  dropout_2 (Dropout)         (None, 24, 32, 128)          0         ['conv2d_5[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 12, 16, 128)          0         ['dropout_2[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 12, 16, 256)          295168    ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 12, 16, 256)          590080    ['conv2d_6[0][0]']
#
#  dropout_3 (Dropout)         (None, 12, 16, 256)          0         ['conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 6, 8, 256)            0         ['dropout_3[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 6, 8, 512)            1180160   ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 6, 8, 512)            2359808   ['conv2d_8[0][0]']
#
#  dropout_4 (Dropout)         (None, 6, 8, 512)            0         ['conv2d_9[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 3, 4, 512)            0         ['dropout_4[0][0]']
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 3, 4, 1024)           4719616   ['max_pooling2d_4[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 3, 4, 1024)           9438208   ['conv2d_10[0][0]']
#
#  dropout_5 (Dropout)         (None, 3, 4, 1024)           0         ['conv2d_11[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 6, 8, 512)            4719104   ['dropout_5[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 6, 8, 1024)           0         ['conv2d_transpose[0][0]',
#                                                                      'dropout_4[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 6, 8, 512)            4719104   ['concatenate[0][0]']
#
#  dropout_6 (Dropout)         (None, 6, 8, 512)            0         ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 6, 8, 512)            2359808   ['dropout_6[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 12, 16, 256)          1179904   ['conv2d_13[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 12, 16, 512)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'dropout_3[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 12, 16, 256)          1179904   ['concatenate_1[0][0]']
#
#  dropout_7 (Dropout)         (None, 12, 16, 256)          0         ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 12, 16, 256)          590080    ['dropout_7[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 24, 32, 128)          295040    ['conv2d_15[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 24, 32, 256)          0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'dropout_2[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 24, 32, 128)          295040    ['concatenate_2[0][0]']
#
#  dropout_8 (Dropout)         (None, 24, 32, 128)          0         ['conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 24, 32, 128)          147584    ['dropout_8[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 48, 64, 64)           73792     ['conv2d_17[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 48, 64, 128)          0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'dropout_1[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 48, 64, 64)           73792     ['concatenate_3[0][0]']
#
#  dropout_9 (Dropout)         (None, 48, 64, 64)           0         ['conv2d_18[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 48, 64, 64)           36928     ['dropout_9[0][0]']
#
#  conv2d_transpose_4 (Conv2D  (None, 96, 128, 32)          18464     ['conv2d_19[0][0]']
#  Transpose)
#
#  concatenate_4 (Concatenate  (None, 96, 128, 64)          0         ['conv2d_transpose_4[0][0]',
#  )                                                                   'dropout[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 96, 128, 32)          18464     ['concatenate_4[0][0]']
#
#  dropout_10 (Dropout)        (None, 96, 128, 32)          0         ['conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 96, 128, 32)          9248      ['dropout_10[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 96, 128, 32)          9248      ['conv2d_21[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 96, 128, 23)          759       ['conv2d_22[0][0]']
#
# ==================================================================================================
# Total params: 34596311 (131.97 MB)
# Trainable params: 34596311 (131.97 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
train_org_images = tf.constant(train_org_image_list)
train_masked_images = tf.constant(train_masked_image_list)
train_dataset = tf.data.Dataset.from_tensor_slices((train_org_images,train_masked_images))
# for image,mask in train_dataset.take(1) :
#     print(image)
#     print(mask)
test_org_images = tf.constant(test_org_image_list)
test_masked_images = tf.constant(test_masked_image_list)
test_dataset = tf.data.Dataset.from_tensor_slices((test_org_images,test_masked_images))
# for image,mask in test_dataset.take(1) :
#     print(image)
#     print(mask)
print(train_org_images[0],train_masked_images[0])
# Out:
# tf.Tensor(b'/content/drive/MyDrive/DLproject/original_images/000.jpg', shape=(), dtype=string) tf.Tensor(b'/content/drive/MyDrive/DLproject/label_images_semantic/000.png', shape=(), dtype=string)

# %%
def process_path(image_path,mask_path):
    org_image = tf.io.read_file(image_path)
    org_image = tf.image.decode_png(org_image,channels=3)
    org_image = tf.image.convert_image_dtype(org_image,tf.float32)

    masked_image = tf.io.read_file(mask_path)
    masked_image = tf.image.decode_png(masked_image,channels=3)
    masked_image = tf.math.reduce_max(masked_image,axis=-1,keepdims=True)
    return org_image , masked_image

def resize(org_image,masked_image) :
    org_image = tf.image.resize(org_image,(final_h,final_w),method='nearest')
    masked_image = tf.image.resize(masked_image,(final_h,final_w),method='nearest')

    return org_image , masked_image

# %%
train_image_data = train_dataset.map(process_path)
print(train_image_data)
final_train_image_data = train_image_data.map(resize)

test_image_data = test_dataset.map(process_path)
print(test_image_data)
final_test_image_data = test_image_data.map(resize)
print(final_train_image_data)
print(final_train_image_data)
# Out:
# <_MapDataset element_spec=(TensorSpec(shape=(None, None, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.uint8, name=None))>
# <_MapDataset element_spec=(TensorSpec(shape=(None, None, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.uint8, name=None))>
# <_MapDataset element_spec=(TensorSpec(shape=(96, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(96, 128, 1), dtype=tf.uint8, name=None))>
# <_MapDataset element_spec=(TensorSpec(shape=(96, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(96, 128, 1), dtype=tf.uint8, name=None))>

# %%
epoch = 500
batch_size=32
buffer = 350

# train
final_train_image_data.batch(batch_size)
final_train_dataset = final_train_image_data.cache().shuffle(buffer).batch(batch_size)
print(final_train_dataset.element_spec)

# validation
final_test_image_data.batch(batch_size)
final_test_dataset = final_test_image_data.cache().shuffle(buffer).batch(batch_size)
print(final_test_dataset.element_spec)

model_history = Unet_model.fit(final_train_dataset,epochs=epoch)
# Out:
# (TensorSpec(shape=(None, 96, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 96, 128, 1), dtype=tf.uint8, name=None))
# (TensorSpec(shape=(None, 96, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 96, 128, 1), dtype=tf.uint8, name=None))
# Epoch 1/500
# 11/11 [==============================] - 212s 796ms/step - loss: 5.5198 - accuracy: 0.2254
# Epoch 2/500
# 11/11 [==============================] - 2s 207ms/step - loss: 2.7204 - accuracy: 0.1262
# Epoch 3/500
# 11/11 [==============================] - 2s 207ms/step - loss: 2.3262 - accuracy: 0.3760
# Epoch 4/500
# 11/11 [==============================] - 2s 209ms/step - loss: 2.1290 - accuracy: 0.4288
# Epoch 5/500
# 11/11 [==============================] - 2s 209ms/step - loss: 2.0088 - accuracy: 0.4700
# Epoch 6/500
# 11/11 [==============================] - 2s 208ms/step - loss: 1.9694 - accuracy: 0.4793
# Epoch 7/500
# 11/11 [==============================] - 2s 209ms/step - loss: 1.8973 - accuracy: 0.4988
# Epoch 8/500
# 11/11 [==============================] - 2s 210ms/step - loss: 1.8678 - accuracy: 0.5046
# Epoch 9/500
# 11/11 [==============================] - 2s 212ms/step - loss: 1.8296 - accuracy: 0.5099
# Epoch 10/500
# 11/11 [==============================] - 2s 212ms/step - loss: 1.7567 - accuracy: 0.5228
# Epoch 11/500
# 11/11 [==============================] - 2s 211ms/step - loss: 1.7127 - accuracy: 0.5350
# Epoch 12/500
# 11/11 [==============================] - 2s 211ms/step - loss: 1.6532 - accuracy: 0.5473
# Epoch 13/500
# 11/11 [==============================] - 2s 211ms/step - loss: 1.6173 - accuracy: 0.5519
# Epoch 14/500
# 11/11 [==============================] - 2s 210ms/step - loss: 1.5560 - accuracy: 0.5667
# Epoch 15/500
# 11/11 [==============================] - 2s 212ms/step - loss: 1.5030 - accuracy: 0.5742
# Epoch 16/500
# 11/11 [==============================] - 2s 211ms/step - loss: 1.5724 - accuracy: 0.5547
# Epoch 17/500
# 11/11 [==============================] - 2s 209ms/step - loss: 1.5439 - accuracy: 0.5551
# Epoch 18/500
# 11/11 [==============================] - 2s 208ms/step - loss: 1.4926 - accuracy: 0.5647
# Epoch 19/500
# 11/11 [==============================] - 2s 208ms/step - loss: 1.4824 - accuracy: 0.5729
# Epoch 20/500
# 11/11 [==============================] - 2s 207ms/step - loss: 1.4634 - accuracy: 0.5730
# Epoch 21/500
# 11/11 [==============================] - 2s 210ms/step - loss: 1.3910 - accuracy: 0.5903
# Epoch 22/500
# 11/11 [==============================] - 2s 209ms/step - loss: 1.3397 - accuracy: 0.6095
# Epoch 23/500
# 11/11 [==============================] - 2s 207ms/step - loss: 1.3381 - accuracy: 0.6121
# Epoch 24/500
# 11/11 [==============================] - 2s 208ms/step - loss: 1.4093 - accuracy: 0.5778
# Epoch 25/500
# 11/11 [==============================] - 2s 206ms/step - loss: 1.3351 - accuracy: 0.6058
# Epoch 26/500
# 11/11 [==============================] - 2s 205ms/step - loss: 1.2804 - accuracy: 0.6232
# Epoch 27/500
# 11/11 [==============================] - 2s 206ms/step - loss: 1.2468 - accuracy: 0.6295
# Epoch 28/500
# 11/11 [==============================] - 2s 206ms/step - loss: 1.2269 - accuracy: 0.6332
# Epoch 29/500
# 11/11 [==============================] - 2s 206ms/step - loss: 1.1961 - accuracy: 0.6407
# Epoch 30/500
# 11/11 [==============================] - 2s 205ms/step - loss: 1.1769 - accuracy: 0.6491
# Epoch 31/500
# 11/11 [==============================] - 2s 206ms/step - loss: 1.1693 - accuracy: 0.6496
# Epoch 32/500
# 11/11 [==============================] - 2s 206ms/step - loss: 1.1704 - accuracy: 0.6526
# Epoch 33/500
# 11/11 [==============================] - 2s 208ms/step - loss: 1.2490 - accuracy: 0.6210
# Epoch 34/500
# 11/11 [==============================] - 2s 206ms/step - loss: 1.2318 - accuracy: 0.6322
# Epoch 35/500
# 11/11 [==============================] - 2s 206ms/step - loss: 1.3097 - accuracy: 0.6084
# Epoch 36/500
# 11/11 [==============================] - 2s 206ms/step - loss: 1.2011 - accuracy: 0.6416
# Epoch 37/500
# 11/11 [==============================] - 2s 207ms/step - loss: 1.1500 - accuracy: 0.6538
# Epoch 38/500
# 11/11 [==============================] - 2s 207ms/step - loss: 1.1319 - accuracy: 0.6591
# Epoch 39/500
# 11/11 [==============================] - 2s 207ms/step - loss: 1.1216 - accuracy: 0.6618
# Epoch 40/500
# 11/11 [==============================] - 2s 207ms/step - loss: 1.1042 - accuracy: 0.6695
# Epoch 41/500
# 11/11 [==============================] - 2s 206ms/step - loss: 1.0894 - accuracy: 0.6689
# Epoch 42/500
# 11/11 [==============================] - 2s 206ms/step - loss: 1.0780 - accuracy: 0.6712
# Epoch 43/500
# 11/11 [==============================] - 2s 207ms/step - loss: 1.0579 - accuracy: 0.6786
# Epoch 44/500
# 11/11 [==============================] - 2s 209ms/step - loss: 1.0363 - accuracy: 0.6864
# Epoch 45/500
# 11/11 [==============================] - 2s 209ms/step - loss: 1.0283 - accuracy: 0.6878
# Epoch 46/500
# 11/11 [==============================] - 2s 208ms/step - loss: 1.0128 - accuracy: 0.6941
# Epoch 47/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.9900 - accuracy: 0.7010
# Epoch 48/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.9715 - accuracy: 0.7067
# Epoch 49/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.9559 - accuracy: 0.7120
# Epoch 50/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.9598 - accuracy: 0.7086
# Epoch 51/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.9421 - accuracy: 0.7160
# Epoch 52/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.9253 - accuracy: 0.7211
# Epoch 53/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.9103 - accuracy: 0.7238
# Epoch 54/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.9142 - accuracy: 0.7233
# Epoch 55/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.8965 - accuracy: 0.7294
# Epoch 56/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.8715 - accuracy: 0.7358
# Epoch 57/500
# 11/11 [==============================] - 2s 207ms/step - loss: 1.0536 - accuracy: 0.6959
# Epoch 58/500
# 11/11 [==============================] - 2s 207ms/step - loss: 1.3778 - accuracy: 0.6070
# Epoch 59/500
# 11/11 [==============================] - 2s 206ms/step - loss: 1.2084 - accuracy: 0.6403
# Epoch 60/500
# 11/11 [==============================] - 2s 206ms/step - loss: 1.1148 - accuracy: 0.6650
# Epoch 61/500
# 11/11 [==============================] - 2s 208ms/step - loss: 1.0693 - accuracy: 0.6790
# Epoch 62/500
# 11/11 [==============================] - 2s 206ms/step - loss: 1.0309 - accuracy: 0.6881
# Epoch 63/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.9993 - accuracy: 0.6993
# Epoch 64/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.9644 - accuracy: 0.7077
# Epoch 65/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.9540 - accuracy: 0.7090
# Epoch 66/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.9480 - accuracy: 0.7108
# Epoch 67/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.9221 - accuracy: 0.7187
# Epoch 68/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.9088 - accuracy: 0.7213
# Epoch 69/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.8803 - accuracy: 0.7298
# Epoch 70/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.8634 - accuracy: 0.7350
# Epoch 71/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.8498 - accuracy: 0.7390
# Epoch 72/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.8467 - accuracy: 0.7416
# Epoch 73/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.8274 - accuracy: 0.7466
# Epoch 74/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.8212 - accuracy: 0.7500
# Epoch 75/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.7994 - accuracy: 0.7544
# Epoch 76/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.7776 - accuracy: 0.7623
# Epoch 77/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.7634 - accuracy: 0.7663
# Epoch 78/500
# 11/11 [==============================] - 2s 211ms/step - loss: 0.7491 - accuracy: 0.7697
# Epoch 79/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.7516 - accuracy: 0.7701
# Epoch 80/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.7522 - accuracy: 0.7689
# Epoch 81/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.7357 - accuracy: 0.7736
# Epoch 82/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.7250 - accuracy: 0.7767
# Epoch 83/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.7184 - accuracy: 0.7792
# Epoch 84/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.7364 - accuracy: 0.7736
# Epoch 85/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.7179 - accuracy: 0.7806
# Epoch 86/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.7016 - accuracy: 0.7849
# Epoch 87/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.6933 - accuracy: 0.7861
# Epoch 88/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.6833 - accuracy: 0.7894
# Epoch 89/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.6641 - accuracy: 0.7949
# Epoch 90/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.6542 - accuracy: 0.7986
# Epoch 91/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.6426 - accuracy: 0.8018
# Epoch 92/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.6331 - accuracy: 0.8033
# Epoch 93/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.6294 - accuracy: 0.8052
# Epoch 94/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.6196 - accuracy: 0.8076
# Epoch 95/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.6185 - accuracy: 0.8080
# Epoch 96/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.6148 - accuracy: 0.8091
# Epoch 97/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.6017 - accuracy: 0.8121
# Epoch 98/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.5931 - accuracy: 0.8159
# Epoch 99/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.5781 - accuracy: 0.8196
# Epoch 100/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.5725 - accuracy: 0.8215
# Epoch 101/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.5693 - accuracy: 0.8222
# Epoch 102/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.5670 - accuracy: 0.8225
# Epoch 103/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.5629 - accuracy: 0.8245
# Epoch 104/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.5529 - accuracy: 0.8265
# Epoch 105/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.5461 - accuracy: 0.8287
# Epoch 106/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.5414 - accuracy: 0.8307
# Epoch 107/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.5330 - accuracy: 0.8334
# Epoch 108/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.5344 - accuracy: 0.8329
# Epoch 109/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.5249 - accuracy: 0.8353
# Epoch 110/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.5216 - accuracy: 0.8364
# Epoch 111/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.5171 - accuracy: 0.8376
# Epoch 112/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.5189 - accuracy: 0.8374
# Epoch 113/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.5212 - accuracy: 0.8362
# Epoch 114/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.5113 - accuracy: 0.8392
# Epoch 115/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4993 - accuracy: 0.8426
# Epoch 116/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4958 - accuracy: 0.8437
# Epoch 117/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.4948 - accuracy: 0.8442
# Epoch 118/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.4888 - accuracy: 0.8456
# Epoch 119/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4858 - accuracy: 0.8469
# Epoch 120/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4807 - accuracy: 0.8483
# Epoch 121/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4764 - accuracy: 0.8496
# Epoch 122/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.4691 - accuracy: 0.8516
# Epoch 123/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.4738 - accuracy: 0.8503
# Epoch 124/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.4665 - accuracy: 0.8526
# Epoch 125/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4638 - accuracy: 0.8530
# Epoch 126/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4581 - accuracy: 0.8546
# Epoch 127/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.4556 - accuracy: 0.8559
# Epoch 128/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4555 - accuracy: 0.8555
# Epoch 129/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.4490 - accuracy: 0.8579
# Epoch 130/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.4455 - accuracy: 0.8586
# Epoch 131/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4463 - accuracy: 0.8586
# Epoch 132/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4598 - accuracy: 0.8554
# Epoch 133/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4876 - accuracy: 0.8465
# Epoch 134/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4760 - accuracy: 0.8495
# Epoch 135/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.4549 - accuracy: 0.8558
# Epoch 136/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.4368 - accuracy: 0.8616
# Epoch 137/500
# 11/11 [==============================] - 2s 206ms/step - loss: 2.5126 - accuracy: 0.4539
# Epoch 138/500
# 11/11 [==============================] - 2s 205ms/step - loss: 2.2184 - accuracy: 0.4453
# Epoch 139/500
# 11/11 [==============================] - 2s 205ms/step - loss: 1.7589 - accuracy: 0.5107
# Epoch 140/500
# 11/11 [==============================] - 2s 207ms/step - loss: 1.5652 - accuracy: 0.5552
# Epoch 141/500
# 11/11 [==============================] - 2s 206ms/step - loss: 1.5605 - accuracy: 0.5357
# Epoch 142/500
# 11/11 [==============================] - 2s 206ms/step - loss: 1.4034 - accuracy: 0.5763
# Epoch 143/500
# 11/11 [==============================] - 2s 206ms/step - loss: 1.3544 - accuracy: 0.6006
# Epoch 144/500
# 11/11 [==============================] - 2s 205ms/step - loss: 1.2804 - accuracy: 0.6204
# Epoch 145/500
# 11/11 [==============================] - 2s 206ms/step - loss: 1.2630 - accuracy: 0.6212
# Epoch 146/500
# 11/11 [==============================] - 2s 209ms/step - loss: 1.2482 - accuracy: 0.6264
# Epoch 147/500
# 11/11 [==============================] - 2s 208ms/step - loss: 1.1946 - accuracy: 0.6443
# Epoch 148/500
# 11/11 [==============================] - 2s 206ms/step - loss: 1.1725 - accuracy: 0.6499
# Epoch 149/500
# 11/11 [==============================] - 2s 206ms/step - loss: 1.1395 - accuracy: 0.6613
# Epoch 150/500
# 11/11 [==============================] - 2s 206ms/step - loss: 1.1745 - accuracy: 0.6497
# Epoch 151/500
# 11/11 [==============================] - 2s 207ms/step - loss: 1.1298 - accuracy: 0.6589
# Epoch 152/500
# 11/11 [==============================] - 2s 208ms/step - loss: 1.0903 - accuracy: 0.6715
# Epoch 153/500
# 11/11 [==============================] - 2s 205ms/step - loss: 1.0679 - accuracy: 0.6777
# Epoch 154/500
# 11/11 [==============================] - 2s 206ms/step - loss: 1.0529 - accuracy: 0.6796
# Epoch 155/500
# 11/11 [==============================] - 2s 207ms/step - loss: 1.0350 - accuracy: 0.6855
# Epoch 156/500
# 11/11 [==============================] - 2s 206ms/step - loss: 1.0225 - accuracy: 0.6883
# Epoch 157/500
# 11/11 [==============================] - 2s 207ms/step - loss: 1.0114 - accuracy: 0.6926
# Epoch 158/500
# 11/11 [==============================] - 2s 207ms/step - loss: 1.0024 - accuracy: 0.6948
# Epoch 159/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.9911 - accuracy: 0.6981
# Epoch 160/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.9751 - accuracy: 0.7010
# Epoch 161/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.9761 - accuracy: 0.7028
# Epoch 162/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.9535 - accuracy: 0.7096
# Epoch 163/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.9346 - accuracy: 0.7157
# Epoch 164/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.9193 - accuracy: 0.7198
# Epoch 165/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.9104 - accuracy: 0.7224
# Epoch 166/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.8859 - accuracy: 0.7288
# Epoch 167/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.8719 - accuracy: 0.7338
# Epoch 168/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.8637 - accuracy: 0.7356
# Epoch 169/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.8528 - accuracy: 0.7377
# Epoch 170/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.8449 - accuracy: 0.7394
# Epoch 171/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.8350 - accuracy: 0.7433
# Epoch 172/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.8237 - accuracy: 0.7454
# Epoch 173/500
# 11/11 [==============================] - 2s 205ms/step - loss: 0.8264 - accuracy: 0.7447
# Epoch 174/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.8097 - accuracy: 0.7499
# Epoch 175/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.8000 - accuracy: 0.7517
# Epoch 176/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.7896 - accuracy: 0.7558
# Epoch 177/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.7775 - accuracy: 0.7590
# Epoch 178/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.7724 - accuracy: 0.7605
# Epoch 179/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.9421 - accuracy: 0.7219
# Epoch 180/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.8883 - accuracy: 0.7301
# Epoch 181/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.8113 - accuracy: 0.7496
# Epoch 182/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.7743 - accuracy: 0.7613
# Epoch 183/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.7539 - accuracy: 0.7660
# Epoch 184/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.7366 - accuracy: 0.7712
# Epoch 185/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.7255 - accuracy: 0.7742
# Epoch 186/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.7189 - accuracy: 0.7756
# Epoch 187/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.7068 - accuracy: 0.7794
# Epoch 188/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.7006 - accuracy: 0.7812
# Epoch 189/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.6918 - accuracy: 0.7839
# Epoch 190/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.6853 - accuracy: 0.7849
# Epoch 191/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.6835 - accuracy: 0.7852
# Epoch 192/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.6743 - accuracy: 0.7883
# Epoch 193/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.6669 - accuracy: 0.7913
# Epoch 194/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.6583 - accuracy: 0.7934
# Epoch 195/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.6475 - accuracy: 0.7966
# Epoch 196/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.6444 - accuracy: 0.7977
# Epoch 197/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.6422 - accuracy: 0.7984
# Epoch 198/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.6369 - accuracy: 0.7995
# Epoch 199/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.6398 - accuracy: 0.7996
# Epoch 200/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.6458 - accuracy: 0.7963
# Epoch 201/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.6372 - accuracy: 0.8004
# Epoch 202/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.6308 - accuracy: 0.8020
# Epoch 203/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.6256 - accuracy: 0.8029
# Epoch 204/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.6177 - accuracy: 0.8057
# Epoch 205/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.6081 - accuracy: 0.8081
# Epoch 206/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.6028 - accuracy: 0.8104
# Epoch 207/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.6011 - accuracy: 0.8105
# Epoch 208/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.6018 - accuracy: 0.8103
# Epoch 209/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.5883 - accuracy: 0.8145
# Epoch 210/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.5811 - accuracy: 0.8165
# Epoch 211/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.5955 - accuracy: 0.8121
# Epoch 212/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.5887 - accuracy: 0.8142
# Epoch 213/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.5823 - accuracy: 0.8168
# Epoch 214/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.5716 - accuracy: 0.8195
# Epoch 215/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.5846 - accuracy: 0.8156
# Epoch 216/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.5832 - accuracy: 0.8169
# Epoch 217/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.5735 - accuracy: 0.8195
# Epoch 218/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.5634 - accuracy: 0.8221
# Epoch 219/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.5508 - accuracy: 0.8260
# Epoch 220/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.5423 - accuracy: 0.8285
# Epoch 221/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.5369 - accuracy: 0.8304
# Epoch 222/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.5315 - accuracy: 0.8323
# Epoch 223/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.5273 - accuracy: 0.8333
# Epoch 224/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.5518 - accuracy: 0.8269
# Epoch 225/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.9251 - accuracy: 0.7319
# Epoch 226/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.8939 - accuracy: 0.7294
# Epoch 227/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.7750 - accuracy: 0.7628
# Epoch 228/500
# 11/11 [==============================] - 2s 205ms/step - loss: 0.7043 - accuracy: 0.7834
# Epoch 229/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.6632 - accuracy: 0.7929
# Epoch 230/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.6229 - accuracy: 0.8047
# Epoch 231/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.5959 - accuracy: 0.8139
# Epoch 232/500
# 11/11 [==============================] - 2s 205ms/step - loss: 0.5714 - accuracy: 0.8204
# Epoch 233/500
# 11/11 [==============================] - 2s 205ms/step - loss: 0.5632 - accuracy: 0.8231
# Epoch 234/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.5503 - accuracy: 0.8268
# Epoch 235/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.5406 - accuracy: 0.8304
# Epoch 236/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.5300 - accuracy: 0.8336
# Epoch 237/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.5224 - accuracy: 0.8356
# Epoch 238/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.5142 - accuracy: 0.8381
# Epoch 239/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.5087 - accuracy: 0.8396
# Epoch 240/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.5074 - accuracy: 0.8407
# Epoch 241/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.5014 - accuracy: 0.8419
# Epoch 242/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.4940 - accuracy: 0.8442
# Epoch 243/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4922 - accuracy: 0.8448
# Epoch 244/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4884 - accuracy: 0.8460
# Epoch 245/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4865 - accuracy: 0.8465
# Epoch 246/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.4847 - accuracy: 0.8470
# Epoch 247/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.4800 - accuracy: 0.8486
# Epoch 248/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.4759 - accuracy: 0.8498
# Epoch 249/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4709 - accuracy: 0.8512
# Epoch 250/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.4663 - accuracy: 0.8527
# Epoch 251/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4638 - accuracy: 0.8536
# Epoch 252/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.4600 - accuracy: 0.8547
# Epoch 253/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.4567 - accuracy: 0.8556
# Epoch 254/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.4557 - accuracy: 0.8556
# Epoch 255/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4536 - accuracy: 0.8564
# Epoch 256/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.4558 - accuracy: 0.8558
# Epoch 257/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.4491 - accuracy: 0.8581
# Epoch 258/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4473 - accuracy: 0.8584
# Epoch 259/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.4437 - accuracy: 0.8598
# Epoch 260/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.4419 - accuracy: 0.8599
# Epoch 261/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.4374 - accuracy: 0.8614
# Epoch 262/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4386 - accuracy: 0.8610
# Epoch 263/500
# 11/11 [==============================] - 2s 212ms/step - loss: 0.4377 - accuracy: 0.8611
# Epoch 264/500
# 11/11 [==============================] - 2s 216ms/step - loss: 0.4320 - accuracy: 0.8632
# Epoch 265/500
# 11/11 [==============================] - 2s 223ms/step - loss: 0.4296 - accuracy: 0.8631
# Epoch 266/500
# 11/11 [==============================] - 2s 218ms/step - loss: 0.4255 - accuracy: 0.8646
# Epoch 267/500
# 11/11 [==============================] - 2s 216ms/step - loss: 0.4264 - accuracy: 0.8645
# Epoch 268/500
# 11/11 [==============================] - 2s 220ms/step - loss: 0.4227 - accuracy: 0.8653
# Epoch 269/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.4186 - accuracy: 0.8669
# Epoch 270/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4180 - accuracy: 0.8667
# Epoch 271/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.4151 - accuracy: 0.8677
# Epoch 272/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.4127 - accuracy: 0.8686
# Epoch 273/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4093 - accuracy: 0.8693
# Epoch 274/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.4062 - accuracy: 0.8704
# Epoch 275/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4041 - accuracy: 0.8711
# Epoch 276/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.4039 - accuracy: 0.8711
# Epoch 277/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.4023 - accuracy: 0.8713
# Epoch 278/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4016 - accuracy: 0.8718
# Epoch 279/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.4013 - accuracy: 0.8719
# Epoch 280/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.4011 - accuracy: 0.8717
# Epoch 281/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3960 - accuracy: 0.8733
# Epoch 282/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3923 - accuracy: 0.8745
# Epoch 283/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.3927 - accuracy: 0.8743
# Epoch 284/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3895 - accuracy: 0.8750
# Epoch 285/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3897 - accuracy: 0.8752
# Epoch 286/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3862 - accuracy: 0.8763
# Epoch 287/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3871 - accuracy: 0.8761
# Epoch 288/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.3861 - accuracy: 0.8763
# Epoch 289/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3831 - accuracy: 0.8771
# Epoch 290/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3852 - accuracy: 0.8766
# Epoch 291/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3829 - accuracy: 0.8774
# Epoch 292/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.3797 - accuracy: 0.8781
# Epoch 293/500
# 11/11 [==============================] - 2s 218ms/step - loss: 0.3772 - accuracy: 0.8787
# Epoch 294/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3745 - accuracy: 0.8798
# Epoch 295/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3740 - accuracy: 0.8797
# Epoch 296/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3713 - accuracy: 0.8804
# Epoch 297/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3688 - accuracy: 0.8814
# Epoch 298/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3653 - accuracy: 0.8822
# Epoch 299/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.3671 - accuracy: 0.8815
# Epoch 300/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3674 - accuracy: 0.8817
# Epoch 301/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3646 - accuracy: 0.8825
# Epoch 302/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.3665 - accuracy: 0.8816
# Epoch 303/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3649 - accuracy: 0.8823
# Epoch 304/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3595 - accuracy: 0.8840
# Epoch 305/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.3582 - accuracy: 0.8844
# Epoch 306/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3562 - accuracy: 0.8848
# Epoch 307/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3574 - accuracy: 0.8846
# Epoch 308/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3535 - accuracy: 0.8853
# Epoch 309/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3536 - accuracy: 0.8858
# Epoch 310/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.3534 - accuracy: 0.8857
# Epoch 311/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3511 - accuracy: 0.8867
# Epoch 312/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3492 - accuracy: 0.8870
# Epoch 313/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3458 - accuracy: 0.8881
# Epoch 314/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.3454 - accuracy: 0.8882
# Epoch 315/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3442 - accuracy: 0.8886
# Epoch 316/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.3422 - accuracy: 0.8893
# Epoch 317/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3431 - accuracy: 0.8888
# Epoch 318/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3413 - accuracy: 0.8890
# Epoch 319/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.3403 - accuracy: 0.8894
# Epoch 320/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3392 - accuracy: 0.8901
# Epoch 321/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.3374 - accuracy: 0.8903
# Epoch 322/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3370 - accuracy: 0.8904
# Epoch 323/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3342 - accuracy: 0.8914
# Epoch 324/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3343 - accuracy: 0.8915
# Epoch 325/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.3338 - accuracy: 0.8915
# Epoch 326/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3325 - accuracy: 0.8918
# Epoch 327/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.3307 - accuracy: 0.8924
# Epoch 328/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.3280 - accuracy: 0.8931
# Epoch 329/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3310 - accuracy: 0.8922
# Epoch 330/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3319 - accuracy: 0.8920
# Epoch 331/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3435 - accuracy: 0.8893
# Epoch 332/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.4934 - accuracy: 0.8489
# Epoch 333/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.5849 - accuracy: 0.8231
# Epoch 334/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.5319 - accuracy: 0.8359
# Epoch 335/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.4485 - accuracy: 0.8581
# Epoch 336/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.4127 - accuracy: 0.8689
# Epoch 337/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3909 - accuracy: 0.8748
# Epoch 338/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.3766 - accuracy: 0.8792
# Epoch 339/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3604 - accuracy: 0.8837
# Epoch 340/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3493 - accuracy: 0.8873
# Epoch 341/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3415 - accuracy: 0.8895
# Epoch 342/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3364 - accuracy: 0.8908
# Epoch 343/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3309 - accuracy: 0.8927
# Epoch 344/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.3270 - accuracy: 0.8939
# Epoch 345/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3263 - accuracy: 0.8937
# Epoch 346/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3240 - accuracy: 0.8945
# Epoch 347/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3204 - accuracy: 0.8956
# Epoch 348/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3192 - accuracy: 0.8959
# Epoch 349/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.3183 - accuracy: 0.8961
# Epoch 350/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3156 - accuracy: 0.8968
# Epoch 351/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3138 - accuracy: 0.8977
# Epoch 352/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3124 - accuracy: 0.8976
# Epoch 353/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3123 - accuracy: 0.8977
# Epoch 354/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3102 - accuracy: 0.8986
# Epoch 355/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.3097 - accuracy: 0.8986
# Epoch 356/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3071 - accuracy: 0.8996
# Epoch 357/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3049 - accuracy: 0.8999
# Epoch 358/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3054 - accuracy: 0.8998
# Epoch 359/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3039 - accuracy: 0.9007
# Epoch 360/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3037 - accuracy: 0.9002
# Epoch 361/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.3017 - accuracy: 0.9011
# Epoch 362/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3015 - accuracy: 0.9008
# Epoch 363/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3015 - accuracy: 0.9011
# Epoch 364/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2994 - accuracy: 0.9016
# Epoch 365/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2984 - accuracy: 0.9020
# Epoch 366/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2968 - accuracy: 0.9024
# Epoch 367/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2973 - accuracy: 0.9019
# Epoch 368/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2966 - accuracy: 0.9022
# Epoch 369/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2957 - accuracy: 0.9025
# Epoch 370/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2948 - accuracy: 0.9029
# Epoch 371/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2935 - accuracy: 0.9032
# Epoch 372/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.2913 - accuracy: 0.9042
# Epoch 373/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2921 - accuracy: 0.9037
# Epoch 374/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.2907 - accuracy: 0.9040
# Epoch 375/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2901 - accuracy: 0.9043
# Epoch 376/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2888 - accuracy: 0.9046
# Epoch 377/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2900 - accuracy: 0.9040
# Epoch 378/500
# 11/11 [==============================] - 2s 211ms/step - loss: 0.2883 - accuracy: 0.9048
# Epoch 379/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2870 - accuracy: 0.9050
# Epoch 380/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2871 - accuracy: 0.9050
# Epoch 381/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2892 - accuracy: 0.9043
# Epoch 382/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2879 - accuracy: 0.9048
# Epoch 383/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2873 - accuracy: 0.9048
# Epoch 384/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2879 - accuracy: 0.9046
# Epoch 385/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2852 - accuracy: 0.9055
# Epoch 386/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2845 - accuracy: 0.9058
# Epoch 387/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2842 - accuracy: 0.9058
# Epoch 388/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2834 - accuracy: 0.9062
# Epoch 389/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2811 - accuracy: 0.9066
# Epoch 390/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2797 - accuracy: 0.9071
# Epoch 391/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2795 - accuracy: 0.9072
# Epoch 392/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2792 - accuracy: 0.9070
# Epoch 393/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2780 - accuracy: 0.9080
# Epoch 394/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.2769 - accuracy: 0.9081
# Epoch 395/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2767 - accuracy: 0.9079
# Epoch 396/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2752 - accuracy: 0.9084
# Epoch 397/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2751 - accuracy: 0.9085
# Epoch 398/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2753 - accuracy: 0.9083
# Epoch 399/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2730 - accuracy: 0.9088
# Epoch 400/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2723 - accuracy: 0.9092
# Epoch 401/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2730 - accuracy: 0.9090
# Epoch 402/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2752 - accuracy: 0.9083
# Epoch 403/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2766 - accuracy: 0.9077
# Epoch 404/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2748 - accuracy: 0.9083
# Epoch 405/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2728 - accuracy: 0.9091
# Epoch 406/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2713 - accuracy: 0.9095
# Epoch 407/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2700 - accuracy: 0.9099
# Epoch 408/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2687 - accuracy: 0.9101
# Epoch 409/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2681 - accuracy: 0.9104
# Epoch 410/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2682 - accuracy: 0.9103
# Epoch 411/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2677 - accuracy: 0.9108
# Epoch 412/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.2691 - accuracy: 0.9101
# Epoch 413/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2686 - accuracy: 0.9104
# Epoch 414/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2676 - accuracy: 0.9108
# Epoch 415/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2659 - accuracy: 0.9112
# Epoch 416/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2665 - accuracy: 0.9109
# Epoch 417/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2654 - accuracy: 0.9114
# Epoch 418/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2660 - accuracy: 0.9110
# Epoch 419/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2654 - accuracy: 0.9112
# Epoch 420/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2634 - accuracy: 0.9116
# Epoch 421/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2619 - accuracy: 0.9122
# Epoch 422/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2596 - accuracy: 0.9129
# Epoch 423/500
# 11/11 [==============================] - 2s 211ms/step - loss: 0.2606 - accuracy: 0.9125
# Epoch 424/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2610 - accuracy: 0.9127
# Epoch 425/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2605 - accuracy: 0.9127
# Epoch 426/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2600 - accuracy: 0.9130
# Epoch 427/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2599 - accuracy: 0.9130
# Epoch 428/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2602 - accuracy: 0.9126
# Epoch 429/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2577 - accuracy: 0.9133
# Epoch 430/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2582 - accuracy: 0.9132
# Epoch 431/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2565 - accuracy: 0.9137
# Epoch 432/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2574 - accuracy: 0.9134
# Epoch 433/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2581 - accuracy: 0.9133
# Epoch 434/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2561 - accuracy: 0.9138
# Epoch 435/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2553 - accuracy: 0.9143
# Epoch 436/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2560 - accuracy: 0.9138
# Epoch 437/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2550 - accuracy: 0.9142
# Epoch 438/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2570 - accuracy: 0.9136
# Epoch 439/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2569 - accuracy: 0.9136
# Epoch 440/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2608 - accuracy: 0.9125
# Epoch 441/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2567 - accuracy: 0.9138
# Epoch 442/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2575 - accuracy: 0.9135
# Epoch 443/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2665 - accuracy: 0.9108
# Epoch 444/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2754 - accuracy: 0.9078
# Epoch 445/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2714 - accuracy: 0.9088
# Epoch 446/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.2610 - accuracy: 0.9122
# Epoch 447/500
# 11/11 [==============================] - 2s 206ms/step - loss: 0.2577 - accuracy: 0.9136
# Epoch 448/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2547 - accuracy: 0.9142
# Epoch 449/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2533 - accuracy: 0.9147
# Epoch 450/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2505 - accuracy: 0.9153
# Epoch 451/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.2477 - accuracy: 0.9163
# Epoch 452/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2483 - accuracy: 0.9159
# Epoch 453/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2482 - accuracy: 0.9162
# Epoch 454/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2467 - accuracy: 0.9164
# Epoch 455/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2477 - accuracy: 0.9161
# Epoch 456/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2465 - accuracy: 0.9164
# Epoch 457/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2451 - accuracy: 0.9171
# Epoch 458/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2472 - accuracy: 0.9165
# Epoch 459/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2479 - accuracy: 0.9163
# Epoch 460/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2484 - accuracy: 0.9160
# Epoch 461/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2485 - accuracy: 0.9160
# Epoch 462/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2459 - accuracy: 0.9167
# Epoch 463/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2442 - accuracy: 0.9172
# Epoch 464/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2433 - accuracy: 0.9175
# Epoch 465/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2423 - accuracy: 0.9179
# Epoch 466/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2426 - accuracy: 0.9178
# Epoch 467/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2420 - accuracy: 0.9179
# Epoch 468/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2417 - accuracy: 0.9183
# Epoch 469/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2422 - accuracy: 0.9177
# Epoch 470/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2403 - accuracy: 0.9184
# Epoch 471/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2391 - accuracy: 0.9189
# Epoch 472/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2403 - accuracy: 0.9185
# Epoch 473/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2403 - accuracy: 0.9184
# Epoch 474/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.2400 - accuracy: 0.9184
# Epoch 475/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2386 - accuracy: 0.9192
# Epoch 476/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2374 - accuracy: 0.9194
# Epoch 477/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2361 - accuracy: 0.9198
# Epoch 478/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2361 - accuracy: 0.9196
# Epoch 479/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.2366 - accuracy: 0.9194
# Epoch 480/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.2383 - accuracy: 0.9188
# Epoch 481/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2387 - accuracy: 0.9186
# Epoch 482/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2375 - accuracy: 0.9192
# Epoch 483/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2392 - accuracy: 0.9185
# Epoch 484/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2396 - accuracy: 0.9185
# Epoch 485/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2371 - accuracy: 0.9193
# Epoch 486/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2372 - accuracy: 0.9192
# Epoch 487/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2370 - accuracy: 0.9194
# Epoch 488/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2393 - accuracy: 0.9185
# Epoch 489/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2390 - accuracy: 0.9187
# Epoch 490/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.2376 - accuracy: 0.9190
# Epoch 491/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2367 - accuracy: 0.9195
# Epoch 492/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2354 - accuracy: 0.9200
# Epoch 493/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2374 - accuracy: 0.9192
# Epoch 494/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2365 - accuracy: 0.9195
# Epoch 495/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2336 - accuracy: 0.9206
# Epoch 496/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2413 - accuracy: 0.9184
# Epoch 497/500
# 11/11 [==============================] - 2s 209ms/step - loss: 0.2431 - accuracy: 0.9173
# Epoch 498/500
# 11/11 [==============================] - 2s 210ms/step - loss: 0.2401 - accuracy: 0.9186
# Epoch 499/500
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2393 - accuracy: 0.9187
# Epoch 500/500
# 11/11 [==============================] - 2s 208ms/step - loss: 0.2366 - accuracy: 0.9196

# %%
plt.plot(model_history.history['accuracy'])

# %%
Unet_model.save("version0.1")
Unet_model =  tf.keras.models.load_model('./version0.1')

# %%
def display(display_list):
    plt.figure(figsize=(15, 15))

    title = ['Input Image', 'True Mask', 'Predicted Mask']

    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
        plt.axis('off')
    plt.show()

def create_mask(pred_mask):
    pred_mask = tf.argmax(pred_mask, axis=-1)
    pred_mask = pred_mask[..., tf.newaxis]
    return pred_mask[0]

def show_predictions(dataset=None, num=1):
    """
    Displays the first image of each of the num batches
    """
    if dataset:
        for image, mask in dataset.take(num):
            pred_mask = Unet_model.predict(image)
            display([image[0], mask[0], create_mask(pred_mask)])
    # else:
    #     display([sample_image, sample_mask,
    #          create_mask(Unet_model.predict(sample_image[tf.newaxis, ...]))])

# %%
print("----- training_dataset results---------")
show_predictions(final_train_dataset, 6)
print("----- validation_dataset results---------")
show_predictions(final_test_dataset, 6)
# Out:
# ----- training_dataset results---------
# 1/1 [==============================] - 0s 478ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 36ms/step
# ----- validation_dataset results---------
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 2s 2s/step

# %%
# model evaluation
print("Unet Model Evaluation: ")
Unet_model.evaluate(final_test_dataset)
# Out:
# Unet Model Evaluation:
# 2/2 [==============================] - 1s 46ms/step - loss: 0.6591 - accuracy: 0.8435
# [0.6591398119926453, 0.8435025811195374]
